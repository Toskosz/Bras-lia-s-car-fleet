# %%
import pandas as pd

# %% [markdown]
# ##Recebendo os Dados

# %%
data = pd.read_csv('frota_ingles.csv', sep=';', encoding='latin-1')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#      Unnamed: 0       2009       2010  ...  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0   Total Fleet  1138127.0  1233000.0  ...          NaN          NaN          NaN
# 1           Car   915448.0   982654.0  ...          NaN          NaN          NaN
# 2    Motorcycle   121547.0   135742.0  ...          NaN          NaN          NaN
# 3         Truck    20293.0    21661.0  ...          NaN          NaN          NaN
# 4  Pickup Truck    48747.0    60121.0  ...          NaN          NaN          NaN
#
# [5 rows x 15 columns]

# %%
data.shape
# Out:
# (12, 15)

# %%
data.describe()
# Out:
#                2009          2010  ...  Unnamed: 13  Unnamed: 14
# count  1.000000e+01  1.000000e+01  ...          0.0          0.0
# mean   2.276254e+05  2.466000e+05  ...          NaN          NaN
# std    4.259817e+05  4.595459e+05  ...          NaN          NaN
# min    1.253000e+03  1.323000e+03  ...          NaN          NaN
# 25%    5.579250e+03  5.610500e+03  ...          NaN          NaN
# 50%    1.782700e+04  1.867300e+04  ...          NaN          NaN
# 75%    1.033470e+05  1.168368e+05  ...          NaN          NaN
# max    1.138127e+06  1.233000e+06  ...          NaN          NaN
#
# [8 rows x 14 columns]

# %%
data
# Out:
#                                       Unnamed: 0  ...  Unnamed: 14
# 0                                    Total Fleet  ...          NaN
# 1                                            Car  ...          NaN
# 2                                     Motorcycle  ...          NaN
# 3                                          Truck  ...          NaN
# 4                                   Pickup Truck  ...          NaN
# 5                                        Trailer  ...          NaN
# 6                                            Bus  ...          NaN
# 7                                      Micro bus  ...          NaN
# 8                                   Semi-trailer  ...          NaN
# 9                                         Others  ...          NaN
# 10                                           NaN  ...          NaN
# 11  (*) Dados apurados atÃ© o mÃªs de junho/2019  ...          NaN
#
# [12 rows x 15 columns]

# %% [markdown]
# ## Formatação dos dados

# %% [markdown]
# Remoção das colunas "extras"

# %%
data = data.drop(data.columns[[12, 13, 14]], axis=1)
data
# Out:
#                                       Unnamed: 0  ...    2019(*)
# 0                                    Total Fleet  ...  1804552.0
# 1                                            Car  ...  1402600.0
# 2                                     Motorcycle  ...   208504.0
# 3                                          Truck  ...    27672.0
# 4                                   Pickup Truck  ...   116911.0
# 5                                        Trailer  ...    24269.0
# 6                                            Bus  ...    12902.0
# 7                                      Micro bus  ...     5901.0
# 8                                   Semi-trailer  ...     4283.0
# 9                                         Others  ...     1510.0
# 10                                           NaN  ...        NaN
# 11  (*) Dados apurados atÃ© o mÃªs de junho/2019  ...        NaN
#
# [12 rows x 12 columns]

# %% [markdown]
# Remoção das linhas "extras"

# %%
data = data.drop(data.index[[10, 11]])
data
# Out:
#      Unnamed: 0       2009       2010  ...       2017       2018    2019(*)
# 0   Total Fleet  1138127.0  1233000.0  ...  1716878.0  1773275.0  1804552.0
# 1           Car   915448.0   982654.0  ...  1338795.0  1380791.0  1402600.0
# 2    Motorcycle   121547.0   135742.0  ...   196292.0   203483.0   208504.0
# 3         Truck    20293.0    21661.0  ...    26814.0    27283.0    27672.0
# 4  Pickup Truck    48747.0    60121.0  ...   108904.0   113883.0   116911.0
# 5       Trailer    15361.0    15685.0  ...    22503.0    23618.0    24269.0
# 6           Bus     8535.0     8618.0  ...    12504.0    12764.0    12902.0
# 7     Micro bus     4594.0     4608.0  ...     5633.0     5833.0     5901.0
# 8  Semi-trailer     2349.0     2588.0  ...     3904.0     4113.0     4283.0
# 9        Others     1253.0     1323.0  ...     1509.0     1507.0     1510.0
#
# [10 rows x 12 columns]

# %% [markdown]
# Renomeação da coluna 0 e retirada do index de numeração

# %%
data.rename( columns={'Unnamed: 0':'Vehicle Type'}, inplace=True )
data
# Out:
#    Vehicle Type       2009       2010  ...       2017       2018    2019(*)
# 0   Total Fleet  1138127.0  1233000.0  ...  1716878.0  1773275.0  1804552.0
# 1           Car   915448.0   982654.0  ...  1338795.0  1380791.0  1402600.0
# 2    Motorcycle   121547.0   135742.0  ...   196292.0   203483.0   208504.0
# 3         Truck    20293.0    21661.0  ...    26814.0    27283.0    27672.0
# 4  Pickup Truck    48747.0    60121.0  ...   108904.0   113883.0   116911.0
# 5       Trailer    15361.0    15685.0  ...    22503.0    23618.0    24269.0
# 6           Bus     8535.0     8618.0  ...    12504.0    12764.0    12902.0
# 7     Micro bus     4594.0     4608.0  ...     5633.0     5833.0     5901.0
# 8  Semi-trailer     2349.0     2588.0  ...     3904.0     4113.0     4283.0
# 9        Others     1253.0     1323.0  ...     1509.0     1507.0     1510.0
#
# [10 rows x 12 columns]

# %%
data = data.set_index('Vehicle Type')
data
# Out:
#                    2009       2010       2011  ...       2017       2018    2019(*)
# Vehicle Type                                   ...
# Total Fleet   1138127.0  1233000.0  1317721.0  ...  1716878.0  1773275.0  1804552.0
# Car            915448.0   982654.0  1042298.0  ...  1338795.0  1380791.0  1402600.0
# Motorcycle     121547.0   135742.0   148535.0  ...   196292.0   203483.0   208504.0
# Truck           20293.0    21661.0    20308.0  ...    26814.0    27283.0    27672.0
# Pickup Truck    48747.0    60121.0    70430.0  ...   108904.0   113883.0   116911.0
# Trailer         15361.0    15685.0    16118.0  ...    22503.0    23618.0    24269.0
# Bus              8535.0     8618.0     8648.0  ...    12504.0    12764.0    12902.0
# Micro bus        4594.0     4608.0     4676.0  ...     5633.0     5833.0     5901.0
# Semi-trailer     2349.0     2588.0     2749.0  ...     3904.0     4113.0     4283.0
# Others           1253.0     1323.0     3959.0  ...     1509.0     1507.0     1510.0
# ...

# %%
data.rename_axis('Year', axis= 'columns', inplace = True)
data
# Out:
# Year               2009       2010       2011  ...       2017       2018    2019(*)
# Vehicle Type                                   ...
# Total Fleet   1138127.0  1233000.0  1317721.0  ...  1716878.0  1773275.0  1804552.0
# Car            915448.0   982654.0  1042298.0  ...  1338795.0  1380791.0  1402600.0
# Motorcycle     121547.0   135742.0   148535.0  ...   196292.0   203483.0   208504.0
# Truck           20293.0    21661.0    20308.0  ...    26814.0    27283.0    27672.0
# Pickup Truck    48747.0    60121.0    70430.0  ...   108904.0   113883.0   116911.0
# Trailer         15361.0    15685.0    16118.0  ...    22503.0    23618.0    24269.0
# Bus              8535.0     8618.0     8648.0  ...    12504.0    12764.0    12902.0
# Micro bus        4594.0     4608.0     4676.0  ...     5633.0     5833.0     5901.0
# Semi-trailer     2349.0     2588.0     2749.0  ...     3904.0     4113.0     4283.0
# Others           1253.0     1323.0     3959.0  ...     1509.0     1507.0     1510.0
# ...

# %% [markdown]
# # Análise de frequência

# %% [markdown]
# ## Porcentagem

# %%
import seaborn as sns
data = data.T
data
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# Vehicle Type  Total Fleet        Car  ...  Semi-trailer  Others
# Year                                  ...
# 2009            1138127.0   915448.0  ...        2349.0  1253.0
# 2010            1233000.0   982654.0  ...        2588.0  1323.0
# 2011            1317721.0  1042298.0  ...        2749.0  3959.0
# 2012            1403788.0  1108253.0  ...        2936.0  4236.0
# 2013            1491539.0  1173712.0  ...        3269.0  4681.0
# 2014            1563382.0  1225757.0  ...        3526.0  4789.0
# 2015            1622396.0  1268403.0  ...        3767.0  4668.0
# 2016            1665165.0  1299450.0  ...        3880.0  1489.0
# 2017            1716878.0  1338795.0  ...        3904.0  1509.0
# 2018            1773275.0  1380791.0  ...        4113.0  1507.0
# ...

# %%
percentage = data.copy(deep=True)
percentage = percentage.drop(data.columns[0], axis=1)
percentage
# Out:
# Vehicle Type        Car  Motorcycle    Truck  ...  Micro bus  Semi-trailer  Others
# Year                                          ...
# 2009           915448.0    121547.0  20293.0  ...     4594.0        2349.0  1253.0
# 2010           982654.0    135742.0  21661.0  ...     4608.0        2588.0  1323.0
# 2011          1042298.0    148535.0  20308.0  ...     4676.0        2749.0  3959.0
# 2012          1108253.0    157992.0  20954.0  ...     4720.0        2936.0  4236.0
# 2013          1173712.0    167489.0  21723.0  ...     4890.0        3269.0  4681.0
# 2014          1225757.0    176658.0  22405.0  ...     5154.0        3526.0  4789.0
# 2015          1268403.0    185138.0  23134.0  ...     5297.0        3767.0  4668.0
# 2016          1299450.0    190440.0  26587.0  ...     5435.0        3880.0  1489.0
# 2017          1338795.0    196292.0  26814.0  ...     5633.0        3904.0  1509.0
# 2018          1380791.0    203483.0  27283.0  ...     5833.0        4113.0  1507.0
# ...

# %%
total_fleet_row = 0
for i in range(0, 11):
  for j in range(0, 9):
    percentage.iloc[i][j] = round((percentage.iloc[i][j]/data.iloc[total_fleet_row][0]) * 100, 2)
  total_fleet_row += 1
percentage
# Out:
# Vehicle Type    Car  Motorcycle  Truck  ...  Micro bus  Semi-trailer  Others
# Year                                    ...
# 2009          80.43       10.68   1.78  ...       0.40          0.21    0.11
# 2010          79.70       11.01   1.76  ...       0.37          0.21    0.11
# 2011          79.10       11.27   1.54  ...       0.35          0.21    0.30
# 2012          78.95       11.25   1.49  ...       0.34          0.21    0.30
# 2013          78.69       11.23   1.46  ...       0.33          0.22    0.31
# 2014          78.40       11.30   1.43  ...       0.33          0.23    0.31
# 2015          78.18       11.41   1.43  ...       0.33          0.23    0.29
# 2016          78.04       11.44   1.60  ...       0.33          0.23    0.09
# 2017          77.98       11.43   1.56  ...       0.33          0.23    0.09
# 2018          77.87       11.47   1.54  ...       0.33          0.23    0.08
# 2019(*)       77.73       11.55   1.53  ...       0.33          0.24    0.08
#
# ...

# %%
percentage.rename_axis('Vehicle Type (%)', axis= 'columns', inplace = True)
percentage
# Out:
# Vehicle Type (%)    Car  Motorcycle  Truck  ...  Micro bus  Semi-trailer  Others
# Year                                        ...
# 2009              80.43       10.68   1.78  ...       0.40          0.21    0.11
# 2010              79.70       11.01   1.76  ...       0.37          0.21    0.11
# 2011              79.10       11.27   1.54  ...       0.35          0.21    0.30
# 2012              78.95       11.25   1.49  ...       0.34          0.21    0.30
# 2013              78.69       11.23   1.46  ...       0.33          0.22    0.31
# 2014              78.40       11.30   1.43  ...       0.33          0.23    0.31
# 2015              78.18       11.41   1.43  ...       0.33          0.23    0.29
# 2016              78.04       11.44   1.60  ...       0.33          0.23    0.09
# 2017              77.98       11.43   1.56  ...       0.33          0.23    0.09
# 2018              77.87       11.47   1.54  ...       0.33          0.23    0.08
# ...

# %%
percentage = percentage.T
percentage
# Out:
# Year               2009   2010   2011   2012  ...   2016   2017   2018  2019(*)
# Vehicle Type (%)                              ...
# Car               80.43  79.70  79.10  78.95  ...  78.04  77.98  77.87    77.73
# Motorcycle        10.68  11.01  11.27  11.25  ...  11.44  11.43  11.47    11.55
# Truck              1.78   1.76   1.54   1.49  ...   1.60   1.56   1.54     1.53
# Pickup Truck       4.28   4.88   5.34   5.65  ...   6.26   6.34   6.42     6.48
# Trailer            1.35   1.27   1.22   1.18  ...   1.29   1.31   1.33     1.34
# Bus                0.75   0.70   0.66   0.63  ...   0.74   0.73   0.72     0.71
# Micro bus          0.40   0.37   0.35   0.34  ...   0.33   0.33   0.33     0.33
# Semi-trailer       0.21   0.21   0.21   0.21  ...   0.23   0.23   0.23     0.24
# Others             0.11   0.11   0.30   0.30  ...   0.09   0.09   0.08     0.08
#
# [9 rows x 11 columns]

# %%
percentage_transposed = percentage.T
percentage_transposed
# Out:
# Vehicle Type (%)    Car  Motorcycle  Truck  ...  Micro bus  Semi-trailer  Others
# Year                                        ...
# 2009              80.43       10.68   1.78  ...       0.40          0.21    0.11
# 2010              79.70       11.01   1.76  ...       0.37          0.21    0.11
# 2011              79.10       11.27   1.54  ...       0.35          0.21    0.30
# 2012              78.95       11.25   1.49  ...       0.34          0.21    0.30
# 2013              78.69       11.23   1.46  ...       0.33          0.22    0.31
# 2014              78.40       11.30   1.43  ...       0.33          0.23    0.31
# 2015              78.18       11.41   1.43  ...       0.33          0.23    0.29
# 2016              78.04       11.44   1.60  ...       0.33          0.23    0.09
# 2017              77.98       11.43   1.56  ...       0.33          0.23    0.09
# 2018              77.87       11.47   1.54  ...       0.33          0.23    0.08
# ...

# %%
data = data.T
data
# Out:
# Vehicle Type  Total Fleet        Car  ...  Semi-trailer  Others
# Year                                  ...
# 2009            1138127.0   915448.0  ...        2349.0  1253.0
# 2010            1233000.0   982654.0  ...        2588.0  1323.0
# 2011            1317721.0  1042298.0  ...        2749.0  3959.0
# 2012            1403788.0  1108253.0  ...        2936.0  4236.0
# 2013            1491539.0  1173712.0  ...        3269.0  4681.0
# 2014            1563382.0  1225757.0  ...        3526.0  4789.0
# 2015            1622396.0  1268403.0  ...        3767.0  4668.0
# 2016            1665165.0  1299450.0  ...        3880.0  1489.0
# 2017            1716878.0  1338795.0  ...        3904.0  1509.0
# 2018            1773275.0  1380791.0  ...        4113.0  1507.0
# 2019(*)         1804552.0  1402600.0  ...        4283.0  1510.0
#
# [11 rows x 10 columns]

# %%
columns = []
for col in data.columns: 
    columns.append(col)
a = []
for x in range(0, len(columns)-1):
    a.append(columns[x+1])
a.append(columns[0])
a
# Out:
# ['Car',
#  'Motorcycle',
#  'Truck',
#  'Pickup Truck',
#  'Trailer',
#  'Bus',
#  'Micro bus',
#  'Semi-trailer',
#  'Others',
#  'Total Fleet']

# %%
data = data.T
data
# Out:
# Year               2009       2010       2011  ...       2017       2018    2019(*)
# Vehicle Type                                   ...
# Total Fleet   1138127.0  1233000.0  1317721.0  ...  1716878.0  1773275.0  1804552.0
# Car            915448.0   982654.0  1042298.0  ...  1338795.0  1380791.0  1402600.0
# Motorcycle     121547.0   135742.0   148535.0  ...   196292.0   203483.0   208504.0
# Truck           20293.0    21661.0    20308.0  ...    26814.0    27283.0    27672.0
# Pickup Truck    48747.0    60121.0    70430.0  ...   108904.0   113883.0   116911.0
# Trailer         15361.0    15685.0    16118.0  ...    22503.0    23618.0    24269.0
# Bus              8535.0     8618.0     8648.0  ...    12504.0    12764.0    12902.0
# Micro bus        4594.0     4608.0     4676.0  ...     5633.0     5833.0     5901.0
# Semi-trailer     2349.0     2588.0     2749.0  ...     3904.0     4113.0     4283.0
# Others           1253.0     1323.0     3959.0  ...     1509.0     1507.0     1510.0
# ...

# %%
teste = data.reindex(a, copy=False)
data = teste
data
# Out:
# Year               2009       2010       2011  ...       2017       2018    2019(*)
# Vehicle Type                                   ...
# Car            915448.0   982654.0  1042298.0  ...  1338795.0  1380791.0  1402600.0
# Motorcycle     121547.0   135742.0   148535.0  ...   196292.0   203483.0   208504.0
# Truck           20293.0    21661.0    20308.0  ...    26814.0    27283.0    27672.0
# Pickup Truck    48747.0    60121.0    70430.0  ...   108904.0   113883.0   116911.0
# Trailer         15361.0    15685.0    16118.0  ...    22503.0    23618.0    24269.0
# Bus              8535.0     8618.0     8648.0  ...    12504.0    12764.0    12902.0
# Micro bus        4594.0     4608.0     4676.0  ...     5633.0     5833.0     5901.0
# Semi-trailer     2349.0     2588.0     2749.0  ...     3904.0     4113.0     4283.0
# Others           1253.0     1323.0     3959.0  ...     1509.0     1507.0     1510.0
# Total Fleet   1138127.0  1233000.0  1317721.0  ...  1716878.0  1773275.0  1804552.0
# ...

# %% [markdown]
# ## Gráfico de barras

# %%
data_transposed = data.T
data_transposed
# Out:
# Vehicle Type        Car  Motorcycle    Truck  ...  Semi-trailer  Others  Total Fleet
# Year                                          ...
# 2009           915448.0    121547.0  20293.0  ...        2349.0  1253.0    1138127.0
# 2010           982654.0    135742.0  21661.0  ...        2588.0  1323.0    1233000.0
# 2011          1042298.0    148535.0  20308.0  ...        2749.0  3959.0    1317721.0
# 2012          1108253.0    157992.0  20954.0  ...        2936.0  4236.0    1403788.0
# 2013          1173712.0    167489.0  21723.0  ...        3269.0  4681.0    1491539.0
# 2014          1225757.0    176658.0  22405.0  ...        3526.0  4789.0    1563382.0
# 2015          1268403.0    185138.0  23134.0  ...        3767.0  4668.0    1622396.0
# 2016          1299450.0    190440.0  26587.0  ...        3880.0  1489.0    1665165.0
# 2017          1338795.0    196292.0  26814.0  ...        3904.0  1509.0    1716878.0
# ...

# %%
data_transposed['Total Fleet'].plot.bar(width=1, color='blue', alpha=0.2, figsize=(12,6))

# %%
data_transposed['Car'].plot.bar(width=1, color='blue', alpha=0.2, figsize=(12,6))

# %%
data_transposed['Others'].plot.bar(width=1, color='blue', alpha=0.2, figsize=(12,6))

# %% [markdown]
# # Dataframe para CSV

# %%
data.to_csv('frota_formatada.csv')

# %%
percentage.to_csv('frota_porcentagem.csv')
